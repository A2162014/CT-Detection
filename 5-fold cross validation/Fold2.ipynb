# %%
import zipfile

# %%
import os
import random
import zipfile
from sklearn.model_selection import train_test_split
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation , GlobalAveragePooling2D ,DepthwiseConv2D ,Input ,Add ,Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import ReLU, LeakyReLU
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping , LearningRateScheduler
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# !pip install tensorflow-addons==0.17.1
import tensorflow_addons as tfa
# Out:
# Collecting tensorflow-addons==0.17.1
#   Downloading tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.17.1) (24.1)
# Collecting typeguard>=2.7 (from tensorflow-addons==0.17.1)
#   Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from typeguard>=2.7->tensorflow-addons==0.17.1) (4.12.2)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.17.1 typeguard-4.3.0
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.7.0 and strictly below 2.10.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# Try 3

# %%
base_path = "/content/drive/MyDrive/Colab Notebooks/Chest_CT_scan_Dataset/fold_2"
train_dir = os.path.join(base_path, 'train')
test_dir = os.path.join(base_path, 'test')

# %%
class_names = os.listdir(train_dir)
file_paths = []
labels = []

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    for file_name in os.listdir(class_path):
        file_paths.append(os.path.join(class_path, file_name))
        labels.append(class_name)

# Convert labels to numerical values
label_to_index = {name: index for index, name in enumerate(class_names)}
labels = [label_to_index[label] for label in labels]

# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(file_paths, labels, test_size=0.2, stratify=labels)

# %%
# Function to create a directory structure for the train and validation sets
def create_data_generator(X, y, dir_name):
    os.makedirs(dir_name, exist_ok=True)
    for class_name in class_names:
        os.makedirs(os.path.join(dir_name, class_name), exist_ok=True)

    for img_path, label in zip(X, y):
        shutil.copy(img_path, os.path.join(dir_name, class_names[label]))

# Create directories for training and validation data
create_data_generator(X_train, y_train, os.path.join(base_path, 'train_split'))
create_data_generator(X_val, y_val, os.path.join(base_path, 'val'))

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255)
val_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
train_generator = train_datagen.flow_from_directory(
    os.path.join(base_path, 'train_split'),
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 759 images belonging to 4 classes.

# %%
validation_generator = val_datagen.flow_from_directory(
    os.path.join(base_path, 'val'),
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 277 images belonging to 4 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 200 images belonging to 4 classes.

# %%
os.makedirs(test_dir, exist_ok=True)

# %%
# Example to list files in the test directory
test_files = os.listdir(test_dir)
print("Number of files in test directory:", len(test_files))
# Out:
# Number of files in test directory: 4

# %%
print("Test directory:", test_dir)
# Out:
# Test directory: /content/drive/MyDrive/Colab Notebooks/Chest_CT_scan_Dataset/fold_2/test

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
METRICS = [
    tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
    tfa.metrics.F1Score(num_classes=4, average="micro", name='f1_score')
]

# %%
# Define the input
input_layer = Input(shape=(224, 224, 3))

# Block 1
x = Conv2D(32, (3,3), activation='relu', padding='same')(input_layer)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# Block 2
x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# Block 3
block3_output = Conv2D(96, (3,3), activation='relu', padding='same')(x)
block3_output = BatchNormalization()(block3_output)
block3_output = MaxPooling2D((2, 2))(block3_output)

# Block 4
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(block3_output)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
block4_branch = Conv2D(64, (1,1), activation='relu', padding='same')(x)
x = Conv2D(160, (3, 3), activation='relu', padding='same')(block4_branch)
x = BatchNormalization()(x)
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)
block4_output = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)

# block3_out = Conv2D(32, (1,1), activation='relu', padding='same')(block3_output)
# block3_out = Conv2D(96, (3, 3), activation='relu', padding='same', dilation_rate=2)(block3_out)
x = Concatenate()([block4_output,  block3_output])
x = MaxPooling2D((2, 2))(x)

# Block 5
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)
x = Conv2D(192, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(96, (1,1), activation='relu', padding='same')(x)
x = Conv2D(224, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)

# MaxPooling before Block 6
main_branch_output = MaxPooling2D((2, 2))(x)
main_branch_output = BatchNormalization()(main_branch_output)

parallel_branch = DepthwiseConv2D(kernel_size=(5,5) ,activation='relu')(block4_branch)
parallel_branch = Conv2D(96, (3,3),padding='same', dilation_rate=2)(parallel_branch)
parallel_branch = BatchNormalization()(parallel_branch)
parallel_branch = ReLU()(parallel_branch)
parallel_branch = MaxPooling2D((2, 2))(parallel_branch)
parallel_branch = DepthwiseConv2D(kernel_size=(5,5) ,activation='relu')(parallel_branch)
# parallel_branch = DepthwiseConv2D(kernel_size=(5,5),activation='relu')(parallel_branch)
parallel_branch = BatchNormalization()(parallel_branch)

main_branch_gap = GlobalAveragePooling2D()(main_branch_output)
parallel_branch_gap = GlobalAveragePooling2D()(parallel_branch)

# Concatenate the GAP outputs
x = Concatenate()([main_branch_gap, parallel_branch_gap])
# x = GlobalAveragePooling2D()(main_branch_output)

# Output layer
output_layer = Dense(4, activation='softmax')(x)

# Define the model
model = Model(inputs=input_layer, outputs=output_layer)

# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 224, 224, 32)         896       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 224, 224, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 32)         0         ['batch_normalization[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)         18496     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 112, 112, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)           0         ['batch_normalization_1[0][0]'
#  g2D)                                                               ]
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 96)           55392     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 96)           384       ['conv2d_2[0][0]']
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 96)           0         ['batch_normalization_2[0][0]'
#  g2D)                                                               ]
#
#  depthwise_conv2d (Depthwis  (None, 28, 28, 96)           960       ['max_pooling2d_2[0][0]']
#  eConv2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)          110720    ['depthwise_conv2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 28, 28, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)           8256      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 160)          92320     ['conv2d_4[0][0]']
#
#  batch_normalization_4 (Bat  (None, 28, 28, 160)          640       ['conv2d_5[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_1 (Depthw  (None, 28, 28, 160)          1600      ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  depthwise_conv2d_2 (Depthw  (None, 28, 28, 160)          1600      ['depthwise_conv2d_1[0][0]']
#  iseConv2D)
#
#  concatenate (Concatenate)   (None, 28, 28, 256)          0         ['depthwise_conv2d_2[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 256)          0         ['concatenate[0][0]']
#  g2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 14, 14, 256)          2560      ['max_pooling2d_3[0][0]']
#  iseConv2D)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 192)          442560    ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 14, 14, 192)          768       ['conv2d_6[0][0]']
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 96)           18528     ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  depthwise_conv2d_6 (Depthw  (None, 24, 24, 64)           1664      ['conv2d_4[0][0]']
#  iseConv2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 224)          193760    ['conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 24, 24, 96)           55392     ['depthwise_conv2d_6[0][0]']
#
#  batch_normalization_6 (Bat  (None, 14, 14, 224)          896       ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 24, 24, 96)           384       ['conv2d_9[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_4 (Depthw  (None, 14, 14, 224)          2240      ['batch_normalization_6[0][0]'
#  iseConv2D)                                                         ]
#
#  re_lu (ReLU)                (None, 24, 24, 96)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  depthwise_conv2d_5 (Depthw  (None, 14, 14, 224)          2240      ['depthwise_conv2d_4[0][0]']
#  iseConv2D)
#
#  max_pooling2d_5 (MaxPoolin  (None, 12, 12, 96)           0         ['re_lu[0][0]']
#  g2D)
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 224)            0         ['depthwise_conv2d_5[0][0]']
#  g2D)
#
#  depthwise_conv2d_7 (Depthw  (None, 8, 8, 96)             2496      ['max_pooling2d_5[0][0]']
#  iseConv2D)
#
#  batch_normalization_7 (Bat  (None, 7, 7, 224)            896       ['max_pooling2d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 8, 8, 96)             384       ['depthwise_conv2d_7[0][0]']
#  chNormalization)
#
#  global_average_pooling2d (  (None, 224)                  0         ['batch_normalization_7[0][0]'
#  GlobalAveragePooling2D)                                            ]
#
#  global_average_pooling2d_1  (None, 96)                   0         ['batch_normalization_9[0][0]'
#   (GlobalAveragePooling2D)                                          ]
#
#  concatenate_1 (Concatenate  (None, 320)                  0         ['global_average_pooling2d[0][
#  )                                                                  0]',
#                                                                      'global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense (Dense)               (None, 4)                    1284      ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 1018212 (3.88 MB)
# Trainable params: 1015588 (3.87 MB)
# Non-trainable params: 2624 (10.25 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=0.0005),
    metrics=METRICS
)

# %%
def lr_schedule(epoch,learning_rate):
  if epoch <7:
    return learning_rate
  else:
    return 0.95*learning_rate

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
# print("Length of train_dataset:", len(train_dataset))
# print("Length of valid_dataset:", len(valid_dataset))

# %%
callbacks = [
    ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1)#,
    # EarlyStopping(monitor="val_loss", patience=10, verbose=1, restore_best_weights=True)
]

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=35,
    callbacks=[callbacks, lr_scheduler],
        verbose=1
    #  , class_weight=class_weights
)
# Out:
# Epoch 1/35
# 48/48 [==============================] - ETA: 0s - loss: 0.9744 - accuracy: 0.5362 - precision: 0.7893 - recall: 0.2912 - auc: 0.8360 - f1_score: 0.5362
# Epoch 1: val_accuracy improved from -inf to 0.30686, saving model to best_model.keras
# 48/48 [==============================] - 138s 3s/step - loss: 0.9744 - accuracy: 0.5362 - precision: 0.7893 - recall: 0.2912 - auc: 0.8360 - f1_score: 0.5362 - val_loss: 1.3785 - val_accuracy: 0.3069 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5535 - val_f1_score: 0.3069 - lr: 5.0000e-04
# Epoch 2/35
# 48/48 [==============================] - ETA: 0s - loss: 0.8068 - accuracy: 0.6930 - precision: 0.7809 - recall: 0.5072 - auc: 0.8978 - f1_score: 0.6930
# Epoch 2: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 6s 124ms/step - loss: 0.8068 - accuracy: 0.6930 - precision: 0.7809 - recall: 0.5072 - auc: 0.8978 - f1_score: 0.6930 - val_loss: 1.3909 - val_accuracy: 0.3069 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5535 - val_f1_score: 0.3069 - lr: 5.0000e-04
# Epoch 3/35
# 48/48 [==============================] - ETA: 0s - loss: 0.5786 - accuracy: 0.7971 - precision: 0.8616 - recall: 0.6970 - auc: 0.9515 - f1_score: 0.7971
# Epoch 3: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 5s 106ms/step - loss: 0.5786 - accuracy: 0.7971 - precision: 0.8616 - recall: 0.6970 - auc: 0.9515 - f1_score: 0.7971 - val_loss: 1.4184 - val_accuracy: 0.2671 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5357 - val_f1_score: 0.2671 - lr: 5.0000e-04
# Epoch 4/35
# 48/48 [==============================] - ETA: 0s - loss: 0.4079 - accuracy: 0.8682 - precision: 0.9042 - recall: 0.8208 - auc: 0.9770 - f1_score: 0.8682
# Epoch 4: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 6s 128ms/step - loss: 0.4079 - accuracy: 0.8682 - precision: 0.9042 - recall: 0.8208 - auc: 0.9770 - f1_score: 0.8682 - val_loss: 1.4762 - val_accuracy: 0.2671 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5445 - val_f1_score: 0.2671 - lr: 5.0000e-04
# Epoch 5/35
# 48/48 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9302 - precision: 0.9515 - recall: 0.9038 - auc: 0.9929 - f1_score: 0.9302
# Epoch 5: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 5s 107ms/step - loss: 0.2484 - accuracy: 0.9302 - precision: 0.9515 - recall: 0.9038 - auc: 0.9929 - f1_score: 0.9302 - val_loss: 1.6086 - val_accuracy: 0.2671 - val_precision: 0.2671 - val_recall: 0.2671 - val_auc: 0.5045 - val_f1_score: 0.2671 - lr: 5.0000e-04
# Epoch 6/35
# 48/48 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9552 - precision: 0.9716 - recall: 0.9460 - auc: 0.9966 - f1_score: 0.9552
# Epoch 6: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 5s 113ms/step - loss: 0.1771 - accuracy: 0.9552 - precision: 0.9716 - recall: 0.9460 - auc: 0.9966 - f1_score: 0.9552 - val_loss: 1.7999 - val_accuracy: 0.2671 - val_precision: 0.2671 - val_recall: 0.2671 - val_auc: 0.5415 - val_f1_score: 0.2671 - lr: 5.0000e-04
# Epoch 7/35
# 48/48 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9710 - precision: 0.9760 - recall: 0.9657 - auc: 0.9975 - f1_score: 0.9710
# Epoch 7: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 5s 104ms/step - loss: 0.1252 - accuracy: 0.9710 - precision: 0.9760 - recall: 0.9657 - auc: 0.9975 - f1_score: 0.9710 - val_loss: 2.1143 - val_accuracy: 0.2671 - val_precision: 0.2671 - val_recall: 0.2671 - val_auc: 0.5315 - val_f1_score: 0.2671 - lr: 5.0000e-04
# Epoch 8/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9908 - precision: 0.9934 - recall: 0.9855 - auc: 0.9993 - f1_score: 0.9908
# Epoch 8: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 6s 125ms/step - loss: 0.0800 - accuracy: 0.9908 - precision: 0.9934 - recall: 0.9855 - auc: 0.9993 - f1_score: 0.9908 - val_loss: 2.5333 - val_accuracy: 0.2671 - val_precision: 0.2671 - val_recall: 0.2671 - val_auc: 0.5591 - val_f1_score: 0.2671 - lr: 4.7500e-04
# Epoch 9/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9881 - precision: 0.9894 - recall: 0.9868 - auc: 0.9998 - f1_score: 0.9881
# Epoch 9: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 5s 105ms/step - loss: 0.0559 - accuracy: 0.9881 - precision: 0.9894 - recall: 0.9868 - auc: 0.9998 - f1_score: 0.9881 - val_loss: 2.8024 - val_accuracy: 0.2671 - val_precision: 0.2671 - val_recall: 0.2671 - val_auc: 0.5825 - val_f1_score: 0.2671 - lr: 4.5125e-04
# Epoch 10/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9895 - precision: 0.9907 - recall: 0.9855 - auc: 0.9997 - f1_score: 0.9895
# Epoch 10: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 5s 112ms/step - loss: 0.0491 - accuracy: 0.9895 - precision: 0.9907 - recall: 0.9855 - auc: 0.9997 - f1_score: 0.9895 - val_loss: 2.9021 - val_accuracy: 0.2671 - val_precision: 0.2671 - val_recall: 0.2671 - val_auc: 0.6185 - val_f1_score: 0.2671 - lr: 4.2869e-04
# Epoch 11/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9921 - precision: 0.9921 - recall: 0.9921 - auc: 0.9997 - f1_score: 0.9921
# Epoch 11: val_accuracy did not improve from 0.30686
# 48/48 [==============================] - 6s 122ms/step - loss: 0.0427 - accuracy: 0.9921 - precision: 0.9921 - recall: 0.9921 - auc: 0.9997 - f1_score: 0.9921 - val_loss: 2.4241 - val_accuracy: 0.2671 - val_precision: 0.2711 - val_recall: 0.2671 - val_auc: 0.7183 - val_f1_score: 0.2671 - lr: 4.0725e-04
# Epoch 12/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9921 - precision: 0.9960 - recall: 0.9921 - auc: 0.9995 - f1_score: 0.9921
# Epoch 12: val_accuracy improved from 0.30686 to 0.58123, saving model to best_model.keras
# 48/48 [==============================] - 6s 130ms/step - loss: 0.0388 - accuracy: 0.9921 - precision: 0.9960 - recall: 0.9921 - auc: 0.9995 - f1_score: 0.9921 - val_loss: 1.0213 - val_accuracy: 0.5812 - val_precision: 0.6367 - val_recall: 0.5632 - val_auc: 0.8429 - val_f1_score: 0.5812 - lr: 3.8689e-04
# Epoch 13/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9999 - f1_score: 0.9947
# Epoch 13: val_accuracy improved from 0.58123 to 0.81949, saving model to best_model.keras
# 48/48 [==============================] - 5s 111ms/step - loss: 0.0295 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9999 - f1_score: 0.9947 - val_loss: 0.4063 - val_accuracy: 0.8195 - val_precision: 0.8836 - val_recall: 0.7401 - val_auc: 0.9736 - val_f1_score: 0.8195 - lr: 3.6755e-04
# Epoch 14/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 0.9998 - f1_score: 0.9960
# Epoch 14: val_accuracy improved from 0.81949 to 0.85560, saving model to best_model.keras
# 48/48 [==============================] - 6s 116ms/step - loss: 0.0227 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 0.9998 - f1_score: 0.9960 - val_loss: 0.3580 - val_accuracy: 0.8556 - val_precision: 0.8647 - val_recall: 0.8303 - val_auc: 0.9763 - val_f1_score: 0.8556 - lr: 3.4917e-04
# Epoch 15/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 15: val_accuracy improved from 0.85560 to 1.00000, saving model to best_model.keras
# 48/48 [==============================] - 6s 124ms/step - loss: 0.0113 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0284 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 3.3171e-04
# Epoch 16/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 0.9992 - f1_score: 0.9974
# Epoch 16: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 105ms/step - loss: 0.0170 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 0.9992 - f1_score: 0.9974 - val_loss: 0.0252 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 3.1512e-04
# Epoch 17/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 1.0000 - f1_score: 0.9960
# Epoch 17: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 6s 125ms/step - loss: 0.0181 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 1.0000 - f1_score: 0.9960 - val_loss: 0.1917 - val_accuracy: 0.9350 - val_precision: 0.9384 - val_recall: 0.9350 - val_auc: 0.9927 - val_f1_score: 0.9350 - lr: 2.9937e-04
# Epoch 18/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 0.9999 - f1_score: 0.9974
# Epoch 18: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 108ms/step - loss: 0.0194 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 0.9999 - f1_score: 0.9974 - val_loss: 0.0821 - val_accuracy: 0.9711 - val_precision: 0.9711 - val_recall: 0.9711 - val_auc: 0.9988 - val_f1_score: 0.9711 - lr: 2.8440e-04
# Epoch 19/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 0.9999 - f1_score: 0.9974
# Epoch 19: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 6s 117ms/step - loss: 0.0164 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 0.9999 - f1_score: 0.9974 - val_loss: 0.0260 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 0.9928 - val_auc: 0.9999 - val_f1_score: 0.9928 - lr: 2.7018e-04
# Epoch 20/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 1.0000 - f1_score: 0.9960
# Epoch 20: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 102ms/step - loss: 0.0155 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9960 - auc: 1.0000 - f1_score: 0.9960 - val_loss: 0.0218 - val_accuracy: 0.9892 - val_precision: 0.9892 - val_recall: 0.9892 - val_auc: 0.9999 - val_f1_score: 0.9892 - lr: 2.5667e-04
# Epoch 21/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 21: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 6s 125ms/step - loss: 0.0086 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0175 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 0.9928 - val_auc: 0.9999 - val_f1_score: 0.9928 - lr: 2.4384e-04
# Epoch 22/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 22: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 105ms/step - loss: 0.0069 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0114 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 2.3165e-04
# Epoch 23/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 23: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 6s 128ms/step - loss: 0.0045 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 0.9999 - val_f1_score: 0.9964 - lr: 2.2006e-04
# Epoch 24/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 24: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 103ms/step - loss: 0.0064 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0142 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 2.0906e-04
# Epoch 25/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 25: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 7s 148ms/step - loss: 0.0048 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0142 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 1.9861e-04
# Epoch 26/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 26: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 103ms/step - loss: 0.0107 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0093 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 1.8868e-04
# Epoch 27/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 27: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 107ms/step - loss: 0.0054 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0121 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 1.7924e-04
# Epoch 28/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 28: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 6s 120ms/step - loss: 0.0077 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0093 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.7028e-04
# Epoch 29/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 29: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 108ms/step - loss: 0.0088 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0130 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 0.9928 - val_auc: 1.0000 - val_f1_score: 0.9928 - lr: 1.6177e-04
# Epoch 30/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 30: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 6s 129ms/step - loss: 0.0074 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0126 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 0.9928 - val_auc: 1.0000 - val_f1_score: 0.9928 - lr: 1.5368e-04
# Epoch 31/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 31: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 104ms/step - loss: 0.0029 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 1.4599e-04
# Epoch 32/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 32: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 108ms/step - loss: 0.0074 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0089 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 1.3869e-04
# Epoch 33/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 33: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 6s 121ms/step - loss: 0.0039 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0078 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 1.3176e-04
# Epoch 34/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 34: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 7s 143ms/step - loss: 0.0042 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0107 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 0.9928 - val_auc: 1.0000 - val_f1_score: 0.9928 - lr: 1.2517e-04
# Epoch 35/35
# 48/48 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974
# Epoch 35: val_accuracy did not improve from 1.00000
# 48/48 [==============================] - 5s 102ms/step - loss: 0.0054 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - auc: 1.0000 - f1_score: 0.9974 - val_loss: 0.0094 - val_accuracy: 0.9964 - val_precision: 0.9964 - val_recall: 0.9964 - val_auc: 1.0000 - val_f1_score: 0.9964 - lr: 1.1891e-04

# %%
def Train_Val_Plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, f1, val_f1):

    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(22, 5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    # Rescale the y-axis for accuracy, auc, precision, and f1
    rescale_factor = 0  # Adjust this factor to control the rescaling

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.set_ylim([0, 1.0])
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.set_ylim([rescale_factor, 1.0])
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.set_ylim([rescale_factor, 1.0])
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.set_ylim([rescale_factor, 1.0])
    ax5.legend(['training', 'validation'])

    plt.show()

# Example usage:
Train_Val_Plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss']
               ,
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['f1_score'], history.history['val_f1_score'])

# %%
model.evaluate(test_generator)
# Out:
# 13/13 [==============================] - 85s 7s/step - loss: 0.0458 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9997 - f1_score: 0.9750
# [0.045786257833242416,
#  0.9750000238418579,
#  0.9750000238418579,
#  0.9750000238418579,
#  0.9997040033340454,
#  0.9750000238418579]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# Load the test dataset
X_test, y_test = [], []
for i in range(len(test_generator)):
    batch_X, batch_y = test_generator[i]
    X_test.append(batch_X)
    y_test.append(batch_y)
X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert the one-hot encoded predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Convert the one-hot encoded true labels to class labels
y_true_classes = np.argmax(y_test, axis=1)

# Create a classification report
report = classification_report(y_true_classes, y_pred_classes)

print(report)
# Out:
# 7/7 [==============================] - 1s 23ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96        68
#            1       1.00      0.95      0.97        37
#            2       1.00      1.00      1.00        43
#            3       0.96      0.98      0.97        52
#
#     accuracy                           0.97       200
#    macro avg       0.98      0.97      0.98       200
# weighted avg       0.98      0.97      0.98       200

# %%
class_names = ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']
# Create a confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plotting the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
