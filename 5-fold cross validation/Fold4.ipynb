# %%
import zipfile

# %%
import os
import random
import zipfile
from sklearn.model_selection import train_test_split
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation , GlobalAveragePooling2D ,DepthwiseConv2D ,Input ,Add ,Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import ReLU, LeakyReLU
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping , LearningRateScheduler
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# !pip install tensorflow-addons==0.17.1
import tensorflow_addons as tfa
# Out:
# Requirement already satisfied: tensorflow-addons==0.17.1 in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.17.1) (24.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.17.1) (4.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from typeguard>=2.7->tensorflow-addons==0.17.1) (4.12.2)

# %% [markdown]
# Try 3

# %%
base_path = "/content/drive/MyDrive/Colab Notebooks/Chest_CT_scan_Dataset/fold_4"
train_dir = os.path.join(base_path, 'train')
test_dir = os.path.join(base_path, 'test')

# %%
class_names = os.listdir(train_dir)
file_paths = []
labels = []

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    for file_name in os.listdir(class_path):
        file_paths.append(os.path.join(class_path, file_name))
        labels.append(class_name)

# Convert labels to numerical values
label_to_index = {name: index for index, name in enumerate(class_names)}
labels = [label_to_index[label] for label in labels]

# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(file_paths, labels, test_size=0.2, stratify=labels)

# %%
# Function to create a directory structure for the train and validation sets
def create_data_generator(X, y, dir_name):
    os.makedirs(dir_name, exist_ok=True)
    for class_name in class_names:
        os.makedirs(os.path.join(dir_name, class_name), exist_ok=True)

    for img_path, label in zip(X, y):
        shutil.copy(img_path, os.path.join(dir_name, class_names[label]))

# Create directories for training and validation data
create_data_generator(X_train, y_train, os.path.join(base_path, 'train_split'))
create_data_generator(X_val, y_val, os.path.join(base_path, 'val'))

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255)
val_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
train_generator = train_datagen.flow_from_directory(
    os.path.join(base_path, 'train_split'),
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 791 images belonging to 4 classes.

# %%
validation_generator = val_datagen.flow_from_directory(
    os.path.join(base_path, 'val'),
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 387 images belonging to 4 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 200 images belonging to 4 classes.

# %%
os.makedirs(test_dir, exist_ok=True)

# %%
# Example to list files in the test directory
test_files = os.listdir(test_dir)
print("Number of files in test directory:", len(test_files))
# Out:
# Number of files in test directory: 4

# %%
print("Test directory:", test_dir)
# Out:
# Test directory: /content/drive/MyDrive/Colab Notebooks/Chest_CT_scan_Dataset/fold_4/test

# %%
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return f1_val

# %%
METRICS = [
    tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
    tfa.metrics.F1Score(num_classes=4, average="micro", name='f1_score')
]

# %%
# Define the input
input_layer = Input(shape=(224, 224, 3))

# Block 1
x = Conv2D(32, (3,3), activation='relu', padding='same')(input_layer)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# Block 2
x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# Block 3
block3_output = Conv2D(96, (3,3), activation='relu', padding='same')(x)
block3_output = BatchNormalization()(block3_output)
block3_output = MaxPooling2D((2, 2))(block3_output)

# Block 4
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(block3_output)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
block4_branch = Conv2D(64, (1,1), activation='relu', padding='same')(x)
x = Conv2D(160, (3, 3), activation='relu', padding='same')(block4_branch)
x = BatchNormalization()(x)
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)
block4_output = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)

# block3_out = Conv2D(32, (1,1), activation='relu', padding='same')(block3_output)
# block3_out = Conv2D(96, (3, 3), activation='relu', padding='same', dilation_rate=2)(block3_out)
x = Concatenate()([block4_output,  block3_output])
x = MaxPooling2D((2, 2))(x)

# Block 5
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)
x = Conv2D(192, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(96, (1,1), activation='relu', padding='same')(x)
x = Conv2D(224, (3,3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)
x = DepthwiseConv2D(kernel_size=(3, 3), padding='same', activation='relu')(x)

# MaxPooling before Block 6
main_branch_output = MaxPooling2D((2, 2))(x)
main_branch_output = BatchNormalization()(main_branch_output)

parallel_branch = DepthwiseConv2D(kernel_size=(5,5) ,activation='relu')(block4_branch)
parallel_branch = Conv2D(96, (3,3),padding='same', dilation_rate=2)(parallel_branch)
parallel_branch = BatchNormalization()(parallel_branch)
parallel_branch = ReLU()(parallel_branch)
parallel_branch = MaxPooling2D((2, 2))(parallel_branch)
parallel_branch = DepthwiseConv2D(kernel_size=(5,5) ,activation='relu')(parallel_branch)
# parallel_branch = DepthwiseConv2D(kernel_size=(5,5),activation='relu')(parallel_branch)
parallel_branch = BatchNormalization()(parallel_branch)

main_branch_gap = GlobalAveragePooling2D()(main_branch_output)
parallel_branch_gap = GlobalAveragePooling2D()(parallel_branch)

# Concatenate the GAP outputs
x = Concatenate()([main_branch_gap, parallel_branch_gap])
# x = GlobalAveragePooling2D()(main_branch_output)

# Output layer
output_layer = Dense(4, activation='softmax')(x)

# Define the model
model = Model(inputs=input_layer, outputs=output_layer)

# Print the model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_10 (Conv2D)          (None, 224, 224, 32)         896       ['input_2[0][0]']
#
#  batch_normalization_10 (Ba  (None, 224, 224, 32)         128       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 112, 112, 32)         0         ['batch_normalization_10[0][0]
#  g2D)                                                               ']
#
#  conv2d_11 (Conv2D)          (None, 112, 112, 64)         18496     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_11 (Ba  (None, 112, 112, 64)         256       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 56, 56, 64)           0         ['batch_normalization_11[0][0]
#  g2D)                                                               ']
#
#  conv2d_12 (Conv2D)          (None, 56, 56, 96)           55392     ['max_pooling2d_7[0][0]']
#
#  batch_normalization_12 (Ba  (None, 56, 56, 96)           384       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 28, 28, 96)           0         ['batch_normalization_12[0][0]
#  g2D)                                                               ']
#
#  depthwise_conv2d_8 (Depthw  (None, 28, 28, 96)           960       ['max_pooling2d_8[0][0]']
#  iseConv2D)
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 128)          110720    ['depthwise_conv2d_8[0][0]']
#
#  batch_normalization_13 (Ba  (None, 28, 28, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 64)           8256      ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 160)          92320     ['conv2d_14[0][0]']
#
#  batch_normalization_14 (Ba  (None, 28, 28, 160)          640       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_9 (Depthw  (None, 28, 28, 160)          1600      ['batch_normalization_14[0][0]
#  iseConv2D)                                                         ']
#
#  depthwise_conv2d_10 (Depth  (None, 28, 28, 160)          1600      ['depthwise_conv2d_9[0][0]']
#  wiseConv2D)
#
#  concatenate_2 (Concatenate  (None, 28, 28, 256)          0         ['depthwise_conv2d_10[0][0]',
#  )                                                                   'max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 256)          0         ['concatenate_2[0][0]']
#  g2D)
#
#  depthwise_conv2d_11 (Depth  (None, 14, 14, 256)          2560      ['max_pooling2d_9[0][0]']
#  wiseConv2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 192)          442560    ['depthwise_conv2d_11[0][0]']
#
#  batch_normalization_15 (Ba  (None, 14, 14, 192)          768       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 96)           18528     ['batch_normalization_15[0][0]
#                                                                     ']
#
#  depthwise_conv2d_14 (Depth  (None, 24, 24, 64)           1664      ['conv2d_14[0][0]']
#  wiseConv2D)
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 224)          193760    ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 24, 24, 96)           55392     ['depthwise_conv2d_14[0][0]']
#
#  batch_normalization_16 (Ba  (None, 14, 14, 224)          896       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 24, 24, 96)           384       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_12 (Depth  (None, 14, 14, 224)          2240      ['batch_normalization_16[0][0]
#  wiseConv2D)                                                        ']
#
#  re_lu_1 (ReLU)              (None, 24, 24, 96)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  depthwise_conv2d_13 (Depth  (None, 14, 14, 224)          2240      ['depthwise_conv2d_12[0][0]']
#  wiseConv2D)
#
#  max_pooling2d_11 (MaxPooli  (None, 12, 12, 96)           0         ['re_lu_1[0][0]']
#  ng2D)
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 224)            0         ['depthwise_conv2d_13[0][0]']
#  ng2D)
#
#  depthwise_conv2d_15 (Depth  (None, 8, 8, 96)             2496      ['max_pooling2d_11[0][0]']
#  wiseConv2D)
#
#  batch_normalization_17 (Ba  (None, 7, 7, 224)            896       ['max_pooling2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 8, 8, 96)             384       ['depthwise_conv2d_15[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_2  (None, 224)                  0         ['batch_normalization_17[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  global_average_pooling2d_3  (None, 96)                   0         ['batch_normalization_19[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  concatenate_3 (Concatenate  (None, 320)                  0         ['global_average_pooling2d_2[0
#  )                                                                  ][0]',
#                                                                      'global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dense_1 (Dense)             (None, 4)                    1284      ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 1018212 (3.88 MB)
# Trainable params: 1015588 (3.87 MB)
# Non-trainable params: 2624 (10.25 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=0.0005),
    metrics=METRICS
)

# %%
def lr_schedule(epoch,learning_rate):
  if epoch <7:
    return learning_rate
  else:
    return 0.95*learning_rate

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
# print("Length of train_dataset:", len(train_dataset))
# print("Length of valid_dataset:", len(valid_dataset))

# %%
callbacks = [
    ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1)#,
    # EarlyStopping(monitor="val_loss", patience=10, verbose=1, restore_best_weights=True)
]

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=35,
    callbacks=[callbacks, lr_scheduler],
        verbose=1
    #  , class_weight=class_weights
)
# Out:
# Epoch 1/35
# 50/50 [==============================] - ETA: 0s - loss: 0.9603 - accuracy: 0.5714 - precision: 0.7516 - recall: 0.2908 - auc: 0.8395 - f1_score: 0.5714
# Epoch 1: val_accuracy improved from -inf to 0.33850, saving model to best_model.keras
# 50/50 [==============================] - 21s 236ms/step - loss: 0.9603 - accuracy: 0.5714 - precision: 0.7516 - recall: 0.2908 - auc: 0.8395 - f1_score: 0.5714 - val_loss: 1.3726 - val_accuracy: 0.3385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5711 - val_f1_score: 0.3385 - lr: 5.0000e-04
# Epoch 2/35
# 50/50 [==============================] - ETA: 0s - loss: 0.7713 - accuracy: 0.6979 - precision: 0.8072 - recall: 0.4817 - auc: 0.9080 - f1_score: 0.6979
# Epoch 2: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 6s 118ms/step - loss: 0.7713 - accuracy: 0.6979 - precision: 0.8072 - recall: 0.4817 - auc: 0.9080 - f1_score: 0.6979 - val_loss: 1.3860 - val_accuracy: 0.3385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5711 - val_f1_score: 0.3385 - lr: 5.0000e-04
# Epoch 3/35
# 50/50 [==============================] - ETA: 0s - loss: 0.5299 - accuracy: 0.8180 - precision: 0.8773 - recall: 0.7320 - auc: 0.9610 - f1_score: 0.8180
# Epoch 3: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 7s 141ms/step - loss: 0.5299 - accuracy: 0.8180 - precision: 0.8773 - recall: 0.7320 - auc: 0.9610 - f1_score: 0.8180 - val_loss: 1.4206 - val_accuracy: 0.3385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5599 - val_f1_score: 0.3385 - lr: 5.0000e-04
# Epoch 4/35
# 50/50 [==============================] - ETA: 0s - loss: 0.4007 - accuracy: 0.8736 - precision: 0.9061 - recall: 0.8293 - auc: 0.9767 - f1_score: 0.8736
# Epoch 4: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 6s 120ms/step - loss: 0.4007 - accuracy: 0.8736 - precision: 0.9061 - recall: 0.8293 - auc: 0.9767 - f1_score: 0.8736 - val_loss: 1.4811 - val_accuracy: 0.3385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5647 - val_f1_score: 0.3385 - lr: 5.0000e-04
# Epoch 5/35
# 50/50 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.9090 - precision: 0.9254 - recall: 0.8938 - auc: 0.9865 - f1_score: 0.9090
# Epoch 5: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 7s 140ms/step - loss: 0.2914 - accuracy: 0.9090 - precision: 0.9254 - recall: 0.8938 - auc: 0.9865 - f1_score: 0.9090 - val_loss: 1.5378 - val_accuracy: 0.3385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5519 - val_f1_score: 0.3385 - lr: 5.0000e-04
# Epoch 6/35
# 50/50 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9494 - precision: 0.9577 - recall: 0.9456 - auc: 0.9964 - f1_score: 0.9494
# Epoch 6: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 7s 134ms/step - loss: 0.1799 - accuracy: 0.9494 - precision: 0.9577 - recall: 0.9456 - auc: 0.9964 - f1_score: 0.9494 - val_loss: 1.6177 - val_accuracy: 0.2972 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5622 - val_f1_score: 0.2972 - lr: 5.0000e-04
# Epoch 7/35
# 50/50 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9709 - precision: 0.9770 - recall: 0.9659 - auc: 0.9983 - f1_score: 0.9709
# Epoch 7: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 7s 131ms/step - loss: 0.1159 - accuracy: 0.9709 - precision: 0.9770 - recall: 0.9659 - auc: 0.9983 - f1_score: 0.9709 - val_loss: 1.6953 - val_accuracy: 0.2610 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5719 - val_f1_score: 0.2610 - lr: 5.0000e-04
# Epoch 8/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0710 - accuracy: 0.9861 - precision: 0.9885 - recall: 0.9823 - auc: 0.9996 - f1_score: 0.9861
# Epoch 8: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 7s 140ms/step - loss: 0.0710 - accuracy: 0.9861 - precision: 0.9885 - recall: 0.9823 - auc: 0.9996 - f1_score: 0.9861 - val_loss: 1.8921 - val_accuracy: 0.2558 - val_precision: 0.2642 - val_recall: 0.2532 - val_auc: 0.5746 - val_f1_score: 0.2558 - lr: 4.7500e-04
# Epoch 9/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - auc: 0.9999 - f1_score: 0.9962
# Epoch 9: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 6s 119ms/step - loss: 0.0423 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - auc: 0.9999 - f1_score: 0.9962 - val_loss: 2.0732 - val_accuracy: 0.2636 - val_precision: 0.2611 - val_recall: 0.2584 - val_auc: 0.6075 - val_f1_score: 0.2636 - lr: 4.5125e-04
# Epoch 10/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9975 - auc: 1.0000 - f1_score: 0.9987
# Epoch 10: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 7s 138ms/step - loss: 0.0231 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9975 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 2.0994 - val_accuracy: 0.2661 - val_precision: 0.2830 - val_recall: 0.2661 - val_auc: 0.6295 - val_f1_score: 0.2661 - lr: 4.2869e-04
# Epoch 11/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9987 - precision: 1.0000 - recall: 0.9975 - auc: 1.0000 - f1_score: 0.9987
# Epoch 11: val_accuracy did not improve from 0.33850
# 50/50 [==============================] - 6s 119ms/step - loss: 0.0212 - accuracy: 0.9987 - precision: 1.0000 - recall: 0.9975 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 2.0611 - val_accuracy: 0.2920 - val_precision: 0.2883 - val_recall: 0.2868 - val_auc: 0.7371 - val_f1_score: 0.2920 - lr: 4.0725e-04
# Epoch 12/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9899 - precision: 0.9924 - recall: 0.9874 - auc: 0.9999 - f1_score: 0.9899
# Epoch 12: val_accuracy improved from 0.33850 to 0.66150, saving model to best_model.keras
# 50/50 [==============================] - 7s 148ms/step - loss: 0.0376 - accuracy: 0.9899 - precision: 0.9924 - recall: 0.9874 - auc: 0.9999 - f1_score: 0.9899 - val_loss: 0.8990 - val_accuracy: 0.6615 - val_precision: 0.6930 - val_recall: 0.6357 - val_auc: 0.8851 - val_f1_score: 0.6615 - lr: 3.8689e-04
# Epoch 13/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9999 - f1_score: 0.9912
# Epoch 13: val_accuracy improved from 0.66150 to 0.66667, saving model to best_model.keras
# 50/50 [==============================] - 6s 120ms/step - loss: 0.0294 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9999 - f1_score: 0.9912 - val_loss: 0.6813 - val_accuracy: 0.6667 - val_precision: 0.6732 - val_recall: 0.6176 - val_auc: 0.9104 - val_f1_score: 0.6667 - lr: 3.6755e-04
# Epoch 14/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 14: val_accuracy improved from 0.66667 to 0.98708, saving model to best_model.keras
# 50/50 [==============================] - 7s 143ms/step - loss: 0.0119 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0806 - val_accuracy: 0.9871 - val_precision: 0.9948 - val_recall: 0.9845 - val_auc: 0.9998 - val_f1_score: 0.9871 - lr: 3.4917e-04
# Epoch 15/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 15: val_accuracy improved from 0.98708 to 0.99742, saving model to best_model.keras
# 50/50 [==============================] - 6s 119ms/step - loss: 0.0114 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0412 - val_accuracy: 0.9974 - val_precision: 0.9974 - val_recall: 0.9974 - val_auc: 1.0000 - val_f1_score: 0.9974 - lr: 3.3171e-04
# Epoch 16/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - auc: 1.0000 - f1_score: 0.9962
# Epoch 16: val_accuracy improved from 0.99742 to 1.00000, saving model to best_model.keras
# 50/50 [==============================] - 7s 142ms/step - loss: 0.0155 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - auc: 1.0000 - f1_score: 0.9962 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 3.1512e-04
# Epoch 17/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 17: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 115ms/step - loss: 0.0109 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9897 - val_precision: 0.9897 - val_recall: 0.9897 - val_auc: 0.9999 - val_f1_score: 0.9897 - lr: 2.9937e-04
# Epoch 18/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987
# Epoch 18: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 132ms/step - loss: 0.0105 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 1.0000 - f1_score: 0.9987 - val_loss: 0.0037 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 2.8440e-04
# Epoch 19/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 19: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 117ms/step - loss: 0.0067 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 2.7018e-04
# Epoch 20/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 20: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 134ms/step - loss: 0.0057 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 2.5667e-04
# Epoch 21/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 21: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 116ms/step - loss: 0.0035 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 2.4384e-04
# Epoch 22/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 22: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 134ms/step - loss: 0.0031 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 3.8845e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 2.3165e-04
# Epoch 23/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 23: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 113ms/step - loss: 0.0011 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 2.3461e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 2.2006e-04
# Epoch 24/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 24: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 113ms/step - loss: 0.0035 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 8.7645e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 2.0906e-04
# Epoch 25/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 25: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 138ms/step - loss: 0.0030 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 3.1344e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.9861e-04
# Epoch 26/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9987 - auc: 1.0000 - f1_score: 1.0000
# Epoch 26: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 112ms/step - loss: 0.0036 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9987 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 2.9832e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.8868e-04
# Epoch 27/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 27: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 137ms/step - loss: 0.0017 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 2.1070e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.7924e-04
# Epoch 28/35
# 50/50 [==============================] - ETA: 0s - loss: 9.5758e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 28: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 115ms/step - loss: 9.5758e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 1.4681e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.7028e-04
# Epoch 29/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 29: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 136ms/step - loss: 0.0014 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 1.3082e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.6177e-04
# Epoch 30/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 30: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 9.1818e-05 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.5368e-04
# Epoch 31/35
# 50/50 [==============================] - ETA: 0s - loss: 9.3391e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 31: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 117ms/step - loss: 9.3391e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 1.1788e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.4599e-04
# Epoch 32/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 32: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 139ms/step - loss: 0.0011 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 1.3101e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.3869e-04
# Epoch 33/35
# 50/50 [==============================] - ETA: 0s - loss: 5.5445e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 33: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 115ms/step - loss: 5.5445e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 1.3694e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.3176e-04
# Epoch 34/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 34: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 7s 138ms/step - loss: 0.0014 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 1.1137e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.2517e-04
# Epoch 35/35
# 50/50 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# Epoch 35: val_accuracy did not improve from 1.00000
# 50/50 [==============================] - 6s 117ms/step - loss: 0.0013 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 1.7510e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.1891e-04

# %%
def Train_Val_Plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, f1, val_f1):

    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(22, 5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    # Rescale the y-axis for accuracy, auc, precision, and f1
    rescale_factor = 0  # Adjust this factor to control the rescaling

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.set_ylim([0, 1.0])
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])

    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.set_ylim([rescale_factor, 1.0])
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.set_ylim([rescale_factor, 1.0])
    ax4.legend(['training', 'validation'])

    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.set_ylim([rescale_factor, 1.0])
    ax5.legend(['training', 'validation'])

    plt.show()

# Example usage:
Train_Val_Plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss']
               ,
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['f1_score'], history.history['val_f1_score'])

# %%
model.evaluate(test_generator)
# Out:
# 13/13 [==============================] - 1s 94ms/step - loss: 0.2305 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9903 - f1_score: 0.9550
# [0.23047664761543274,
#  0.9549999833106995,
#  0.9549999833106995,
#  0.9549999833106995,
#  0.9903457760810852,
#  0.9549999833106995]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# Load the test dataset
X_test, y_test = [], []
for i in range(len(test_generator)):
    batch_X, batch_y = test_generator[i]
    X_test.append(batch_X)
    y_test.append(batch_y)
X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert the one-hot encoded predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Convert the one-hot encoded true labels to class labels
y_true_classes = np.argmax(y_test, axis=1)

# Create a classification report
report = classification_report(y_true_classes, y_pred_classes)

print(report)
# Out:
# 7/7 [==============================] - 0s 33ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        67
#            1       0.94      0.89      0.92        38
#            2       0.93      1.00      0.97        43
#            3       0.96      0.96      0.96        52
#
#     accuracy                           0.95       200
#    macro avg       0.95      0.95      0.95       200
# weighted avg       0.96      0.95      0.95       200

# %%
class_names = ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']
# Create a confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plotting the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
